# %%
import json
import os
from natsort import natsorted # pip install natsort

def merge_JsonFiles(allTozihs,listFiles):

    for onefile in listFiles:
        dirr= f"{filelocation}\\{onefile}"
    #         print(dirr)
        f = open(dirr, "r", encoding='utf8')
        fileRead = json.load(f)
        print(len(allTozihs))
        fileFinal=fileRead[onefile[:-5]]
        allTozihs=allTozihs+list(fileFinal["tozih"].values())
    return allTozihs


allTozihs=[]
for i in range(1,8):
    babcount=i
    print(f"number of bab running is : {i}")
    filelocation=f"G:\\Flutter\\Mafatih\\Kernel_app_kochulo\\kernel_and_bot\\KernelBot\\python\\Babs\\{babcount}"

    listFiles = natsorted(os.listdir(filelocation))  # dir is your directory path
    number_files = len(listFiles)
    
    allTozihs=merge_JsonFiles(allTozihs, listFiles)
# Out:
# number of bab running is : 1
# ['1', '2', '3', '4', '5', '6', '7', 'ListofJsonForSearch2.json', 'about', 'infoBabs.json', 'infobab1.json', 'infobab2.json', 'infobab3.json', 'infobab4.json', 'infobab6.json', 'infobab7.json']
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-37-89a0ab11ce17> in <module>
#      27     number_files = len(listFiles)
#      28
# ---> 29     allTozihs=merge_JsonFiles(allTozihs, listFiles)
#
# <ipython-input-37-89a0ab11ce17> in merge_JsonFiles(allTozihs, listFiles)
#       8         dirr= f"{filelocation}\\{onefile}"
#       9     #         print(dirr)
# ---> 10         f = open(dirr, "r", encoding='utf8')
#      11         fileRead = json.load(f)
#      12         print(len(allTozihs))
#
# PermissionError: [Errno 13] Permission denied: 'G:\\Flutter\\Mafatih\\Kernel_app_kochulo\\kernel_and_bot\\KernelBot\\python\\Babs\\1'

# %%
len(allTozihs)
# Out:
# 3036

# %%
unifiedreturnedAllTozihs=list(set(allTozihs))
len(unifiedreturnedAllTozihs)
# Out:
# 1313

# %%
unifiedreturnedAllTozihs
# Out:
# ['',
#  '\nدر چنین روزی در سال دوم هجری ولادت باسعادت حضرت امام حسن مجتبی(علیه\u200cالسلام) واقع شد و شیخ مفید فرموده: ولادت امام محمّد تقی در چنین روزی در سال صدونودوپنج هجری بوده، اما مشهور از علما برآنند که آن در غیر این روز بوده است، به هر صورت این روز، روز بسیار شریفی است و دادن صدقات و بخشش\u200cها در این روز فضیلت بسیار دارد.',
#  'روایت شده: که از امام صادق(علیه\u200cالسلام) پرسیدند: چه می\u200cفرمایی در حق کسی\u200cکه در شب نیمه ماه رمضان کنار قبر امام حسین(علیه\u200cالسلام) حاضر شود؟\nحضرت فرمود: خوشا به حال کسی\u200cکه در شب نیمه ماه رمضان پس از نماز عشا «ده رکعت» نماز کنار قبر آن حضرت بخواند، البته این نماز غیر از نافله شب است و بخواند در هر رکعت پس از سوره «حمد» «ده مرتبه» «توحید» و به خدای تعالی از آتش دوزخ پناهنده شود، خدا او را نجات یافتگان از آتش ثبت می\u200cکند و از دنیا نرود تا فرشتگانی را در خواب ببیند که او را به بهشت بشارت می\u200cدهند و نیز فرشتگانی که او را از آتش ایمنی می\u200cدهند.',
# ...

# %%
dicUnifiedreturnedAllTozihs={}
for i,item in enumerate(unifiedreturnedAllTozihs):
    dicUnifiedreturnedAllTozihs[f'{i}']=item
    
    
dirDestination="G:\\Python\\AppsWithHj\\Mafatih Translation Json"
dirFinal=f"{dirDestination}\\dicUnifiedreturnedAllTozihs.json"
with open(dirFinal, "w", encoding='utf8') as write_file:
    json.dump(dicUnifiedreturnedAllTozihs, write_file, ensure_ascii=False, indent=4)

# %%
dicUnifiedreturnedAllTozihs
# Out:
# {'0': '',
#  '1': '\nدر چنین روزی در سال دوم هجری ولادت باسعادت حضرت امام حسن مجتبی(علیه\u200cالسلام) واقع شد و شیخ مفید فرموده: ولادت امام محمّد تقی در چنین روزی در سال صدونودوپنج هجری بوده، اما مشهور از علما برآنند که آن در غیر این روز بوده است، به هر صورت این روز، روز بسیار شریفی است و دادن صدقات و بخشش\u200cها در این روز فضیلت بسیار دارد.',
#  '2': 'روایت شده: که از امام صادق(علیه\u200cالسلام) پرسیدند: چه می\u200cفرمایی در حق کسی\u200cکه در شب نیمه ماه رمضان کنار قبر امام حسین(علیه\u200cالسلام) حاضر شود؟\nحضرت فرمود: خوشا به حال کسی\u200cکه در شب نیمه ماه رمضان پس از نماز عشا «ده رکعت» نماز کنار قبر آن حضرت بخواند، البته این نماز غیر از نافله شب است و بخواند در هر رکعت پس از سوره «حمد» «ده مرتبه» «توحید» و به خدای تعالی از آتش دوزخ پناهنده شود، خدا او را نجات یافتگان از آتش ثبت می\u200cکند و از دنیا نرود تا فرشتگانی را در خواب ببیند که او را به بهشت بشارت می\u200cدهند و نیز فرشتگانی که او را از آتش ایمنی می\u200cدهند.',
# ...

# %%
import pandas as pd
df = pd.DataFrame(unifiedreturnedAllTozihs).to_excel("Mafatih Translation Tozihs.xlsx")

# %%
import json
import os
from natsort import natsorted # pip install natsort

def merge_JsonFiles(allTozihs,listFiles):

    for onefile in listFiles:
        dirr= f"{filelocation}\\{onefile}"
    #         print(dirr)
        f = open(dirr, "r", encoding='utf8')
        fileFinal = json.load(f)
#         print(fileFinal)
        for dic in fileFinal:
            allTozihs.append(dic["title"])
            
    return allTozihs


allTozihs=[]

print(f"number of bab running is : {i}")
filelocation=f"G:\\Flutter\\Mafatih\\Kernel_app_kochulo\\kernel_and_bot\\KernelBot\\python\\Babs"

listFiles = natsorted(os.listdir(filelocation))  # dir is your directory path
number_files = len(listFiles)
print(listFiles[9:])

allTozihs=merge_JsonFiles(allTozihs, listFiles[9:])
allTozihs
# Out:
# number of bab running is : 1
# ['infoBabs.json', 'infobab1.json', 'infobab2.json', 'infobab3.json', 'infobab4.json', 'infobab6.json', 'infobab7.json']
# ['ادعیـه',
#  'اعمـال',
#  'زیـارات',
#  'ملحقات',
#  'حاشیـه',
#  'سوره\u200cهایی از قـرآن',
#  'مقدمه',
#  'فصل اول در تعقیبات مشترک',
#  'تعقیبات مشترک',
#  'دعای حضرت یوسف(ع) در زندان ',
#  'دعای تقویت حافظه بعد از هر نماز',
#  'دعای بعد از نماز ظهر برای باز نشدن پرونده گناهان در قیامت ',
#  'دعای بعد از تسبیحات حضرت زهرا',
#  'فصل دوم در تعقیبات مخصوص به هر یک از نمازها',
#  'تعقیب نماز صبح',
#  'تعقیب نماز ظهر',
#  'تعقیب نماز عصر',
#  'تعقیب نماز مغرب',
#  'نماز نافله مغرب ',
#  'نماز غفیله ',
#  'تعقیب نماز عشاء',
#  'دعای رزق و روزی بعد از نماز عشاء',
#  'نماز وتیره ',
#  'دعای امیرالمؤمنین(ع) در شب هجرت وقتی که جای پیامبر(ص) خوابید ',
#  'دعای حفظ از کوری و دیوانگی و فقر بعد از نماز صبح ',
#  'دعای درمان ورم معده، پیسی و دیوانگی بعد از نماز صبح',
#  'دعای درمان درد چشم بعد از نماز صبح',
#  'دعای حاجت بعد از نماز صبح',
# ...

# %%
len(allTozihs)
# Out:
# 773

# %%
unifiedreturnedAllTozihs=list(set(allTozihs))
len(unifiedreturnedAllTozihs)
# Out:
# 771

# %%
dirDestination="G:\\Python\\AppsWithHj\\Mafatih Translation Json"
dirFinal=f"{dirDestination}\\All Titles.json"
with open(dirFinal, "w", encoding='utf8') as write_file:
    json.dump(unifiedreturnedAllTozihs, write_file, ensure_ascii=False, indent=4)

# %%
import pandas as pd
df = pd.DataFrame(unifiedreturnedAllTozihs).to_excel("All Titles.xlsx")

# %%
import pyautogui
import time
import pyperclip

time.sleep(2)     
pyautogui.moveTo(x=200, y=820, duration = 1)
pyautogui.scroll(-200)
time.sleep(2) 
        
pyautogui.click(x=900, y=920, duration = 1)
time.sleep(2)  
pyperclip.copy("1-به روز رسانی پلیر \n 2- قابلیت نصب بر اخرین نسخه اندروید\n 3-قابلیت ادامه فراز \n ")
time.sleep(2)
pyautogui.hotkey("ctrl", "v")
time.sleep(2) 
        
        
pyautogui.moveTo(x=900, y=1000, duration = 1)
time.sleep(2) 
pyautogui.scroll(-100)
time.sleep(2) 
pyautogui.click(x=1210, y=930, duration = 1)
time.sleep(2) 
pyautogui.click(x=1250, y=1010, duration = 1)
time.sleep(2) 
pyautogui.scroll(-300)
pyautogui.click(x=900, y=630, duration = 1)
time.sleep(2)
pyautogui.scroll(-300)
pyautogui.click(x=1100, y=900, duration = 1)

# %%
import pandas
pandas.read_json(dirFinal).to_excel("output.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-4ce9c028236d> in <module>
#       1 import pandas
# ----> 2 pandas.read_json(dirFinal).to_excel("output.xlsx")
#
# c:\users\m.sh\appdata\local\programs\python\python38\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# c:\users\m.sh\appdata\local\programs\python\python38\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     606         return json_reader
#     607
# --> 608     result = json_reader.read()
# ...

# %%
listone = [1, 2, 3, 5]
listtwo = [4, "5", 6]

joinedlist = listone + listtwo
list(set(joinedlist))

# %% [markdown]
# # App kuchulou Translation

# %%
import json
import os
import shutil
import pandas as pd

def merge_JsonFiles(allTozihs,listFiles, jsonfileLocation):

    for onefile in listFiles:
        dirr= f"{jsonfileLocation}/{onefile}"
    #         print(dirr)
        f = open(dirr, "r", encoding='utf8')
        fileRead = json.load(f)
        fileFinal=fileRead[onefile[:-5]]
        try:
            allTozihs=allTozihs+list(fileFinal["tozih"].values())
        except:
            print(dirr)
            pass
    return allTozihs



filelocation=f"G:/Flutter/Mafatih/Kernel_app_kochulo"

listFiles = os.listdir(filelocation) # dir is your directory path
number_files = len(listFiles)
listFiles.sort()

    
allTozihs=[]
for f in listFiles[5:-2]:
            jsonFiles=[]
            jsonfileLocation=f"{filelocation}/{f}/KernelFiles/Babs"
            listSoundFiles = os.listdir(jsonfileLocation)
            for file in listSoundFiles:
                if file.endswith(".json"):
                    jsonFiles.append(file)
        
        
#             print(jsonFiles)
            
#             print(desFolder+f"/{int(mapIds[f])}.mp3")
            allTozihs=merge_JsonFiles(allTozihs, jsonFiles, jsonfileLocation)


allTozihs
# Out:
# G:/Flutter/Mafatih/Kernel_app_kochulo/pydart.nisa/KernelFiles/Babs/2.json
# G:/Flutter/Mafatih/Kernel_app_kochulo/pydart.tahrim/KernelFiles/Babs/2.json
# G:/Flutter/Mafatih/Kernel_app_kochulo/pydart.yasin/KernelFiles/Babs/2.json
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'آنگاه «سه بار» بر ران راست خود دست می\u200cزنی و در هر مرتبه می\u200cگویی:',
#  ' از حضرت صادق(علیه\u200cالسلام) روایت شده: هرکه چهل صبحگاه این عهد را بخواند، از یاوران قائم ما باشد و اگر پیش از ظهور آن حضرت از دنیا برود، خدا او را از قبر بیرون آورد که در خدمت آن حضرت باشد و حق\u200cتعالی بر هر کلمه هزار حسنه به او کرامت فرماید و هزار گناه از او محو سازد و آن عهد این است:',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
len(allTozihs)
# Out:
# 1050

# %%
unifiedreturnedAllTozihs=list(set(allTozihs))
len(unifiedreturnedAllTozihs)
# Out:
# 92

# %%
dicUnifiedreturnedAllTozihs={}
for i,item in enumerate(unifiedreturnedAllTozihs):
    dicUnifiedreturnedAllTozihs[f'{i}']=item
    
    
dirDestination="G:\\Python\\AppsWithHj\\Mafatih Translation Json"
dirFinal=f"{dirDestination}\\dicUnifiedreturnedAllTozihsAppKochulou.json"
with open(dirFinal, "w", encoding='utf8') as write_file:
    json.dump(dicUnifiedreturnedAllTozihs, write_file, ensure_ascii=False, indent=4)

# %% [markdown]
# # Change the file extension for files in a folder

# %%
import os
import sys
folder = 'G:/Flutter/Mafatih/Mafatih/Pythons/python/Babs/1'
for filename in os.listdir(folder):
    infilename = os.path.join(folder,filename)
    if not os.path.isfile(infilename): continue
    oldbase = os.path.splitext(filename)
    newname = infilename.replace('.py', '.json')
    output = os.rename(infilename, newname)
